# %% [markdown]
# Exploratory Data Analysis with our dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
covid = pd.read_csv('//content//Latest Covid-19 India Status.csv')

# %%
covid.head()
# Out:
#              State/UTs  Total Cases  ...  Death Ratio  Population
# 0  Andaman and Nicobar         8397  ...         1.54      399001
# 1       Andhra Pradesh      2087879  ...         0.69    91702478
# 2    Arunachal Pradesh        56010  ...         0.50     1711947
# 3                Assam       635050  ...         0.97    35998752
# 4                Bihar       762458  ...         1.59   128500364
#
# [5 rows x 9 columns]

# %%
covid.shape
# Out:
# (36, 9)

# %%
covid.isnull()

# %%
covid.isnull().sum()
# Out:
# State/UTs          0
# Total Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active Ratio       0
# Discharge Ratio    0
# Death Ratio        0
# Population         0
# dtype: int64

# %%
sns.heatmap(covid.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#sns.set_style('whitegrid')
sns.countplot(x='State/UTs', data=covid )

# %%
plt(y='Total Cases', x='Active')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Active',hue='Discharged',data=covid,palette='rainbow')

# %%
covid ['Discharged'].hist(bins=30,color='darkred',alpha=0.5)

# %%
sns.countplot(x='Deaths',data=covid)

# %%
covid.corr()
#heatmap
# Out:
#                  Total Cases    Active  ...  Death Ratio  Population
# Total Cases         1.000000  0.860484  ...     0.100452    0.525734
# Active              0.860484  1.000000  ...     0.206191    0.566020
# Discharged          0.999776  0.849776  ...     0.093860    0.522039
# Deaths              0.935526  0.920939  ...     0.246828    0.483275
# Active Ratio       -0.025761  0.249863  ...     0.215939    0.103380
# Discharge Ratio    -0.000841 -0.279725  ...    -0.446854   -0.106384
# Death Ratio         0.100452  0.206191  ...     1.000000    0.047525
# Population          0.525734  0.566020  ...     0.047525    1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(covid.corr())

# %%
Distribution plots
distplot
joinplot
pairplot

# %%
sns.pairplot(covid)

# %%
sns.distplot(covid['Total Cases'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(covid['Active'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(covid['Discharged'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(covid,hue='Discharge Ratio')

# %%
sns.distplot(covid['Death Ratio'],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
