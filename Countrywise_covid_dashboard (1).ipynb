# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

from plotly.subplots import make_subplots

import folium


import plotly.express as px
from plotly.subplots import make_subplots


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

from datetime import timedelta

# %%
df=pd.read_csv('//content//country_daywise.csv')

# %%
df
# Out:
#               Date      Country  Confirmed  Deaths  Recovered  Active  \
# 0       23-01-2020  Afghanistan          0       0          0       0
# 1       24-01-2020  Afghanistan          0       0          0       0
# 2       25-01-2020  Afghanistan          0       0          0       0
# 3       26-01-2020  Afghanistan          0       0          0       0
# 4       27-01-2020  Afghanistan          0       0          0       0
# ...            ...          ...        ...     ...        ...     ...
# 150277  15-02-2022     Zimbabwe     231603    5374          0  226229
# 150278  16-02-2022     Zimbabwe     232213    5379          0  226834
# 150279  17-02-2022     Zimbabwe     232598    5381          0  227217
# 150280  18-02-2022     Zimbabwe     233030    5385          0  227645
# 150281  22-01-2020  Afghanistan          0       0          0       0
#
#         New Cases  New Recovered  New Deaths
# 0               0              0           0
# 1               0              0           0
# 2               0              0           0
# 3               0              0           0
# 4               0              0           0
# ...           ...            ...         ...
# 150277          0              0           0
# 150278        610              0           5
# 150279        385              0           2
# 150280        432              0           4
# 150281          0              0           0
#
# [150282 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150282 entries, 0 to 150281
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           150282 non-null  object
#  1   Country        150282 non-null  object
#  2   Confirmed      150282 non-null  int64
#  3   Deaths         150282 non-null  int64
#  4   Recovered      150282 non-null  int64
#  5   Active         150282 non-null  int64
#  6   New Cases      150282 non-null  int64
#  7   New Recovered  150282 non-null  int64
#  8   New Deaths     150282 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 10.3+ MB

# %%
confirmed=df.groupby('Date').sum()['Confirmed'].reset_index()
confirmed
# Out:
#            Date  Confirmed
# 0    01-01-2021   84332710
# 1    01-01-2022  289847451
# 2    01-02-2020      12038
# 3    01-02-2021  103755123
# 4    01-02-2022  382154874
# ..          ...        ...
# 755  31-08-2021  218276305
# 756  31-10-2020   46138526
# 757  31-10-2021  247427191
# 758  31-12-2020   83760090
# 759  31-12-2021  288650698
#
# [760 rows x 2 columns]

# %%
recovered=df.groupby('Date').sum()['Recovered'].reset_index()
recovered
# Out:
#            Date  Recovered
# 0    2020-01-23         32
# 1    2020-01-24         39
# 2    2020-01-25         42
# 3    2020-01-26         56
# 4    2020-01-27         65
# ..          ...        ...
# 754  2022-02-15          0
# 755  2022-02-16          0
# 756  2022-02-17          0
# 757  2022-02-18          0
# 758  2022-02-19          0
#
# [759 rows x 2 columns]

# %%
df.query('Country == "US"')
# Out:
#               Date Country  Confirmed  ...  New Cases  New Recovered  New Deaths
# 138897  2020-01-23      US          1  ...          0              0           0
# 138898  2020-01-24      US          2  ...          1              0           0
# 138899  2020-01-25      US          2  ...          0              0           0
# 138900  2020-01-26      US          5  ...          3              0           0
# 138901  2020-01-27      US          5  ...          0              0           0
# ...            ...     ...        ...  ...        ...            ...         ...
# 139651  2022-02-15      US   78059110  ...     115055              0        2595
# 139652  2022-02-16      US   78174363  ...     115253              0        3083
# 139653  2022-02-17      US   78275698  ...     101335              0        3223
# 139654  2022-02-18      US   78423525  ...     147827              0        2459
# 139655  2022-02-19      US   78457081  ...      33556              0         630
#
# [759 rows x 9 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=confirmed['Date'],y= confirmed['Confirmed'], mode= 'lines+maekers'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4fa9f859-3edc-41cd-81ee-6d1249dfc187" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fa9f859-3edc-41cd-81ee-6d1249dfc187")) {                    Plotly.newPlot(                        "4fa9f859-3edc-41cd-81ee-6d1249dfc187",                        [{"mode":"lines+markers","x":["2020-01-23","2020-01-24","2020-01-25","2020-01-26","2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02-17","2020-02-18","2020-02-19","2020-02-20","2020-02-21","2020-02-22","2020-02-23","2020-02-24","2020-02-25","2020-02-26","2020-02-27","2020-02-28","2020-02-29","2020-03-01","2020-03-02","2020-03-03","2020-03-04","2020-03-05","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20","2020-06-21","2020-06-22","2020-06-23","2020-06-24","2020-06-25","2020-06-26","2020-06-27","2020-06-28","2020-06-29","2020-06-30","2020-07-01","2020-07-02","2020-07-03","2020-07-04","2020-07-05","2020-07-06","2020-07-07","2020-07-08","2020-07-09","2020-07-10","2020-07-11","2020-07-12","2020-07-13","2020-07-14","2020-07-15","2020-07-16","2020-07-17","2020-07-18","2020-07-19","2020-07-20","2020-07-21","2020-07-22","2020-07-23","2020-07-24","2020-07-25","2020-07-26","2020-07-27","2020-07-28","2020-07-29","2020-07-30","2020-07-31","2020-08-01","2020-08-02","2020-08-03","2020-08-04","2020-08-05","2020-08-06","2020-08-07","2020-08-08","2020-08-09","2020-08-10","2020-08-11","2020-08-12","2020-08-13","2020-08-14","2020-08-15","2020-08-16","2020-08-17","2020-08-18","2020-08-19","2020-08-20","2020-08-21","2020-08-22","2020-08-23","2020-08-24","2020-08-25","2020-08-26","2020-08-27","2020-08-28","2020-08-29","2020-08-30","2020-08-31","2020-09-01","2020-09-02","2020-09-03","2020-09-04","2020-09-05","2020-09-06","2020-09-07","2020-09-08","2020-09-09","2020-09-10","2020-09-11","2020-09-12","2020-09-13","2020-09-14","2020-09-15","2020-09-16","2020-09-17","2020-09-18","2020-09-19","2020-09-20","2020-09-21","2020-09-22","2020-09-23","2020-09-24","2020-09-25","2020-09-26","2020-09-27","2020-09-28","2020-09-29","2020-09-30","2020-10-01","2020-10-02","2020-10-03","2020-10-04","2020-10-05","2020-10-06","2020-10-07","2020-10-08","2020-10-09","2020-10-10","2020-10-11","2020 ...
